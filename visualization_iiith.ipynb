# %% [markdown]
# <a href="https://colab.research.google.com/github/johnny3125/AIML-Training-Johnny/blob/main/visualization_iiith.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
x=np.random.random(100)
y=np.random.normal(size=100)

# %%
sns.histplot(y,color='blue',fill=True);
sns.kdeplot(y,color='magenta',fill=True);

# %%
tips_df=sns.load_dataset('tips')

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print(tips_df.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
print(tips_df.tail(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print(tips_df.sample(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 34        17.78  3.27    Male     No   Sat  Dinner     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 223       15.98  3.00  Female     No   Fri   Lunch     3

# %%
tips_df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
tips_df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.histplot(tips_df.tip/tips_df.total_bill);

# %%
tips_df[tips_df.tip/tips_df.total_bill>0.5]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
tips_df[tips_df['day']=='Sun']['day'].count()
days=tips_df.day.unique()
day_data={}
for each_day in days:
  day_data[each_day]=[tips_df[tips_df['day']==each_day]['day'].count()]
  print(day_data)
# Out:
# {'Sun': [76]}
# {'Sun': [76], 'Sat': [87]}
# {'Sun': [76], 'Sat': [87], 'Thur': [62]}
# {'Sun': [76], 'Sat': [87], 'Thur': [62], 'Fri': [19]}

# %%
day_df=pd.DataFrame(day_data)

# %%
sns.barplot(day_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-5687a5cdff86> in <cell line: 1>()
# ----> 1 sns.barplot(day_data)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     504
#     505                 # The input data is a flat list
# --> 506                 elif np.isscalar(data[0]):
#     507                     plot_data = [data]
#     508
#
# KeyError: 0

# %%
tips_df.groupby('day')['day'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: day, dtype: int64

# %%
tips_series=tips_df.groupby('day')['day'].count()
sns.barplot(x=tips_series.index,y=tips_series.values)
# Out:
# <Axes: xlabel='day'>

# %%
sns.relplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.regplot(data=tips_df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.lmplot(data=tips_df[tips_df.sex=='Female'],x='total_bill',y='tip')

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day',col='smoker',row='sex');

# %%
sns.pairplot(tips_df)

# %% [markdown]
# # Composition of Data

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,explode=[1,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7be7991b2440>,
#   <matplotlib.patches.Wedge at 0x7be7991b2350>,
#   <matplotlib.patches.Wedge at 0x7be7991b35b0>,
#   <matplotlib.patches.Wedge at 0x7be7991b3e80>],
#  [Text(1.465682748092455, 1.5039195729639767, 'Thur'),
#   Text(-0.29381052431802407, 1.060035554026358, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')],
#  [Text(1.116710665213299, 1.1458434841630298, '25.41%'),
#   Text(-0.16026028599164946, 0.5782012112871043, '7.79%'),
#   Text(-0.5987571167776049, -0.038599418495225794, '35.66%'),
#   Text(0.3349461613939807, -0.4978062564567036, '31.15%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',wedgeprops=dict(width=0.25));
