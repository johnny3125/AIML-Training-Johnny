# %% [markdown]
# <a href="https://colab.research.google.com/github/johnny3125/AIML-Training-Johnny/blob/main/Day2_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 2: Assignmnet
#
# Task 1:Data Transformation
#     try creating different coordinate system and plot MNIST data in coordinate system which best separates the data
#     Consider housing data, filter rows based on sqft_living >2000 sqft and plot the trend of price in this filtered data.
#     Create a small table with categorical data, numerical data and null values. try to find the correlation between those columns.
#
# Task 2:KNN
#     Try to predict the class label based on k values 3,5,7
#     Try KNN using different distance metrics
#
# Task 3: Regression
#     Try with different values of alpha(regularization parameter) for both ridge and lasso and observe the results
#     Try with higher degrees in polynomial Regression
#
# Task 4:Clustering (marked as homework in notebook)
#     Try creating K-Means algorithm from scratch
#     Plot the clusters

# %%
#Sample code from ChatGPT
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import pandas as pd

# Load MNIST dataset
mnist = fetch_openml("mnist_784")
X = mnist.data
y = mnist.target.astype(int)

# Dimensionality reduction using PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot MNIST data in PCA coordinate system
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap="jet", marker=".", alpha=0.5)
plt.title("MNIST Data in PCA Coordinate System")
plt.colorbar()
plt.show()

# Load housing data (assuming you have a CSV file)
housing_data = pd.read_csv("housing.csv")

# Filter rows based on sqft_living > 2000 sqft
filtered_data = housing_data[housing_data["sqft_living"] > 2000]

# Plot trend of "price" column in filtered data
plt.figure(figsize=(10, 5))
plt.plot(filtered_data["price"], label="Price")
plt.xlabel("Data Point")
plt.ylabel("Price")
plt.title("Trend of Price in Housing Data (sqft_living > 2000 sqft)")
plt.legend()
plt.show()

# Create a small table with categorical, numerical, and null values
data = {
    "Category": ["A", "B", "C", "A", "B"],
    "Number": [10, 20, 30, 40, 50],
    "Nullable": [None, 5, None, 15, 25],
}
df = pd.DataFrame(data)

# Calculate correlation matrix
correlation_matrix = df.corr()

# Display correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# %% [markdown]
# Task 1: Data Transformation

# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import pandas as pd

# %%
# Load MNIST dataset
mnist = fetch_openml("mnist_784",parser="auto")
X = mnist.data
y = mnist.target.astype(int)

# %%
print(X.head)
print(y.head)
# Out:
# <bound method NDFrame.head of 0        5
# 1        0
# 2        4
# 3        1
# 4        9
#         ..
# 69995    2
# 69996    3
# 69997    4
# 69998    5
# 69999    6
# Name: class, Length: 70000, dtype: int64>

# %%
# Dimensionality reduction using PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
print(X_pca)
# Out:
# array([[ 122.25324402, -316.22764391],
#        [1010.49460191, -289.98128546],
#        [ -58.9955545 ,  393.70319762],
#        ...,
#        [-271.50861124,  590.08933291],
#        [-310.22459562, -116.70736549],
#        [1058.86144502,  -83.40671357]])

# %%
# Plot MNIST data in PCA coordinate system
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap="jet", marker=".", alpha=0.5)
plt.title("MNIST Data in PCA Coordinate System")
plt.colorbar()
plt.show()

# %%
# Load housing data (assuming you have a CSV file)
housing_data = pd.read_csv("kc_house_data.csv")

# %%
print(housing_data.head)
# Out:
# <bound method NDFrame.head of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# Filter rows based on sqft_living > 2000 sqft
filtered_data = housing_data[housing_data["sqft_living"] > 2000]

# %%
filtered_data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# ...           ...              ...        ...       ...        ...
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %%
# Plot trend of "price" column in filtered data
plt.figure(figsize=(10, 5))
plt.plot(filtered_data["price"], label="Price")
plt.xlabel("Data Point")
plt.ylabel("Price")
plt.title("Trend of Price in Housing Data (sqft_living > 2000 sqft)")
plt.legend()
plt.show()

# %%
# Create a small table with categorical, numerical, and null values
data = {
    "Category": ["A", "B", "C", "A", "B"],
    "Number": [10, 20, 30, 40, 50],
    "Nullable": [None, 5, None, 15, 25],
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Category  Number  Nullable
# 0        A      10       NaN
# 1        B      20       5.0
# 2        C      30       NaN
# 3        A      40      15.0
# 4        B      50      25.0

# %%
# Calculate correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# %%
# Display correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#             Number  Nullable
# Number    1.000000  0.981981
# Nullable  0.981981  1.000000

# %% [markdown]
# Task 2:KNN Try to predict the class label based on k values 3,5,7 Try KNN using different distance metrics

# %% [markdown]
# Notes:
# 1. We load a sample dataset (the Iris dataset) from scikit-learn.
# 2. We split the dataset into training and testing sets using train_test_split.
# 3. We define a list of k values (3, 5, and 7) and a list of distance metrics (Euclidean, Manhattan, and Chebyshev).
# 4. We iterate through the k values and distance metrics and train a KNN classifier for each combination.
# 5. For each combination, we calculate the accuracy of the classifier on the test data using accuracy_score from scikit-learn.

# %%
#Sample code from chatGPT
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load a sample dataset (e.g., the Iris dataset)
iris = datasets.load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define different values of k
k_values = [3, 5, 7]

# Define different distance metrics
distance_metrics = ['euclidean', 'manhattan', 'chebyshev']

# Iterate through k values and distance metrics
for k in k_values:
    for metric in distance_metrics:
        # Create a KNN classifier with the current k and distance metric
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)

        # Fit the classifier on the training data
        knn.fit(X_train, y_train)

        # Make predictions on the test data
        y_pred = knn.predict(X_test)

        # Calculate and print the accuracy
        accuracy = accuracy_score(y_test, y_pred)
        print(f'KNN (k={k}, metric={metric}): Accuracy = {accuracy:.2f}')

# %%
#load libraries
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# Load a sample dataset (e.g., the Iris dataset)
iris = datasets.load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define different values of k
k_values = [3, 5, 7]

# %%
# Define different distance metrics
distance_metrics = ['euclidean', 'manhattan', 'chebyshev']

# %%
# Iterate through k values and distance metrics
for k in k_values:
    for metric in distance_metrics:
        # Create a KNN classifier with the current k and distance metric
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)

        # Fit the classifier on the training data
        knn.fit(X_train, y_train)

        # Make predictions on the test data
        y_pred = knn.predict(X_test)

        # Calculate and print the accuracy
        accuracy = accuracy_score(y_test, y_pred)
        print(f'KNN (k={k}, metric={metric}): Accuracy = {accuracy:.2f}')
# Out:
# KNN (k=3, metric=euclidean): Accuracy = 1.00
# KNN (k=3, metric=manhattan): Accuracy = 1.00
# KNN (k=3, metric=chebyshev): Accuracy = 1.00
# KNN (k=5, metric=euclidean): Accuracy = 1.00
# KNN (k=5, metric=manhattan): Accuracy = 1.00
# KNN (k=5, metric=chebyshev): Accuracy = 0.98
# KNN (k=7, metric=euclidean): Accuracy = 1.00
# KNN (k=7, metric=manhattan): Accuracy = 1.00
# KNN (k=7, metric=chebyshev): Accuracy = 1.00

# %%
k_values = [3,5,7]
accuracy_values = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_values.append(accuracy)

plt.plot(k_values, accuracy_values, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Neighbors (k)')
plt.grid(True)
plt.show()

# %% [markdown]
# Task 3: Regression Try with different values of alpha(regularization parameter) for both ridge and lasso and observe the results Try with higher degrees in polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# Generate synthetic data
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define a range of alpha values to try for Ridge and Lasso
alpha_values = [0.001, 0.01, 0.1, 1, 10, 100]

# Initialize lists to store results
ridge_rmse = []
lasso_rmse = []

# Try different alpha values for Ridge and Lasso regression
for alpha in alpha_values:
    # Ridge Regression
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train, y_train)
    ridge_pred = ridge.predict(X_test)
    ridge_rmse.append(np.sqrt(mean_squared_error(y_test, ridge_pred)))

    # Lasso Regression
    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, y_train)
    lasso_pred = lasso.predict(X_test)
    lasso_rmse.append(np.sqrt(mean_squared_error(y_test, lasso_pred)))

# Plot RMSE vs. Alpha for Ridge and Lasso
plt.figure(figsize=(10, 5))
plt.plot(alpha_values, ridge_rmse, label='Ridge')
plt.plot(alpha_values, lasso_rmse, label='Lasso')
plt.xlabel('Alpha (Regularization Parameter)')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('RMSE vs. Alpha for Ridge and Lasso')
plt.legend()
plt.grid(True)
plt.show()

# Try polynomial regression with different degrees
degrees = [1, 2, 3, 4, 5]

for degree in degrees:
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X_train)

    model = LinearRegression()
    model.fit(X_poly, y_train)

    X_test_poly = poly.transform(X_test)
    y_poly_pred = model.predict(X_test_poly)

    rmse = np.sqrt(mean_squared_error(y_test, y_poly_pred))
    print(f'Degree {degree} Polynomial Regression RMSE: {rmse:.2f}')

# %%
#load necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
# Generate synthetic data
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define a range of alpha values to try for Ridge and Lasso
alpha_values = [0.001, 0.01, 0.1, 1, 10, 100]

# %%
# Initialize lists to store results
ridge_rmse = []
lasso_rmse = []

# %%
# Try different alpha values for Ridge and Lasso regression
for alpha in alpha_values:
    # Ridge Regression
    ridge = Ridge(alpha=alpha)
    ridge.fit(X_train, y_train)
    ridge_pred = ridge.predict(X_test)
    ridge_rmse.append(np.sqrt(mean_squared_error(y_test, ridge_pred)))

    # Lasso Regression
    lasso = Lasso(alpha=alpha)
    lasso.fit(X_train, y_train)
    lasso_pred = lasso.predict(X_test)
    lasso_rmse.append(np.sqrt(mean_squared_error(y_test, lasso_pred)))

# %%
# Plot RMSE vs. Alpha for Ridge and Lasso
plt.figure(figsize=(10, 5))
plt.plot(alpha_values, ridge_rmse, label='Ridge')
plt.plot(alpha_values, lasso_rmse, label='Lasso')
plt.xlabel('Alpha (Regularization Parameter)')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('RMSE vs. Alpha for Ridge and Lasso')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Try polynomial regression with different degrees
degrees = [1, 2, 3, 4, 5]

for degree in degrees:
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X_train)

    model = LinearRegression()
    model.fit(X_poly, y_train)

    X_test_poly = poly.transform(X_test)
    y_poly_pred = model.predict(X_test_poly)

    rmse = np.sqrt(mean_squared_error(y_test, y_poly_pred))
    print(f'Degree {degree} Polynomial Regression RMSE: {rmse:.2f}')
# Out:
# Degree 1 Polynomial Regression RMSE: 10.17
# Degree 2 Polynomial Regression RMSE: 10.18
# Degree 3 Polynomial Regression RMSE: 10.18
# Degree 4 Polynomial Regression RMSE: 10.13
# Degree 5 Polynomial Regression RMSE: 10.13
